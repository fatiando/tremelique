# %%
import numpy as np
import matplotlib.pyplot as plt
from _utils import create_homogeneous_model 
from _acoustic import Acoustic
from _wavelets import RickerWavelet

shape = (300, 400)
spacing = 5
propriedades_acusticas = {"velocity": 1500, "density": 1000}

model = create_homogeneous_model(shape, propriedades_acusticas)


sim = Acoustic(
    velocity=model["velocity"], 
    density=model["density"], 
    spacing=spacing,
    verbose=True
)

sim.add_point_source((0, shape[1]//2), RickerWavelet(1,60))

sim.run(400)

anim = sim.animate(every=10, embed=True, cutoff=0.5)
anim
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 25
#      21 sim.add_point_source((0, shape[1]//2), RickerWavelet(1,60))
#      23 sim.run(400)
# ---> 25 anim = sim.animate(every=10, embed=True, cutoff=0.5, dpi=50)
#      26 anim
#
# File c:\Users\paulo\Documents\GitHub\tremelique\src\tremelique\_acoustic.py:327, in Acoustic.animate(self, every, cutoff, ax, cmap, embed, fps, dpi, **kwargs)
#     325 anim = animation.FuncAnimation(fig, plot, frames=frames, **kwargs)
#     326 if embed:
# --> 327     return anim_to_html(anim, fps=fps, dpi=dpi)
#     328 plt.show()
#     329 return anim
#
# File c:\Users\paulo\Documents\GitHub\tremelique\src\tremelique\_utils.py:39, in anim_to_html(anim, fps, dpi)
#      37     temporary_file = pathlib.Path(tmp.name)
#      38 try:
# ---> 39     anim.save(
#      40         temporary_file,
#      41         fps=fps,
#      42         dpi=dpi,
#      43         writer="ffmpeg",
#      44         extra_args=["-vcodec", "libx264"],
#      45     )
#      46     with temporary_file.open(mode="rb") as videofile:
#      47         video = videofile.read()
#
# File c:\Users\paulo\miniforge3\envs\tremelique-env\Lib\site-packages\matplotlib\animation.py:1075, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1072         writer_cls = PillowWriter  # Always available.
#    1073         _log.warning("MovieWriter %s unavailable; using Pillow "
#    1074                      "instead.", writer)
# -> 1075     writer = writer_cls(fps, **writer_kwargs)
#    1076 _log.info('Animation.save using %s', type(writer))
#    1078 if 'bbox_inches' in savefig_kwargs:
#
# TypeError: AbstractMovieWriter.__init__() got an unexpected keyword argument 'extra_args'
